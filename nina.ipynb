# %%
#import dependenceis
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
#view data sources
ILI_data_path = 'FluViewPhase2Data (2)/ILINet.csv'
clin_data_path = 'FluViewPhase2Data (2)/WHO_NREVSS_Clinical_Labs.csv'
#pub_data_path = 'FluViewPhase2Data (2)/WHO_NREVSS_Public_Health_Labs.csv'

#read data sources
ILI_data = pd.read_csv(ILI_data_path, skiprows = 1)
clin_data = pd.read_csv(clin_data_path)
#pub_data = pd.read_csv(pub_data_path)

# %%
#view ILI
ILI_df = pd.DataFrame(ILI_data)

#remove null values
ILI_drop = ILI_df.drop(ILI_df.column['% WEIGHTED ILI']== 'X', inplace=True)

ILI_drop.head(11)

#convert datatypes of columns to float
#ILI_df[['','NUM. OF PROVIDERS']].apply(pd.to_numeric)



#clean ILI
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-4bef105a21c6> in <module>
#       3
#       4 #remove null values
# ----> 5 ILI_drop = ILI_df.drop(ILI_df['% WEIGHTED ILI']== 'X', inplace=True)
#       6
#       7 ILI_drop.head(11)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: '[ True  True  True ...  True  True  True] not found in axis'

# %%
ILI_df.head(11)
# Out:
#    REGION TYPE                REGION  YEAR  WEEK % WEIGHTED ILI  \
# 0       States               Alabama  2016    40              X
# 1       States                Alaska  2016    40              X
# 2       States               Arizona  2016    40              X
# 3       States              Arkansas  2016    40              X
# 4       States            California  2016    40              X
# 5       States              Colorado  2016    40              X
# 6       States           Connecticut  2016    40              X
# 7       States              Delaware  2016    40              X
# 8       States  District of Columbia  2016    40              X
# 9       States               Florida  2016    40              X
# 10      States               Georgia  2016    40              X
#
#    %UNWEIGHTED ILI AGE 0-4 AGE 25-49 AGE 25-64 AGE 5-24 AGE 50-64 AGE 65  \
# 0          2.22398       X         X         X        X         X      X
# 1         0.940228       X         X         X        X         X      X
# 2          1.23442       X         X         X        X         X      X
# 3         0.917431       X         X         X        X         X      X
# 4          1.25288       X         X         X        X         X      X
# 5          0.77574       X         X         X        X         X      X
# 6          1.23552       X         X         X        X         X      X
# 7         0.104858       X         X         X        X         X      X
# 8          5.52486       X         X         X        X         X      X
# 9                X       X         X         X        X         X      X
# 10         1.62466       X         X         X        X         X      X
#
#    ILITOTAL NUM. OF PROVIDERS TOTAL PATIENTS
# 0       169                23           7599
# 1        14                 6           1489
# 2       309                49          25032
# 3        40                13           4360
# 4       668               129          53317
# 5        22                 5           2836
# 6        64                19           5180
# 7         3                12           2861
# 8       160                 2           2896
# 9         X                 X              X
# 10      903                53          55581

# %%
#view clinical
clin_df = pd.DataFrame(clin_data)

clin_df.head(10)

#clean clinical
# Out:
#                                                                                                       *Beginning for the 2015-16 season, reports from public health and clinical laboratories are presented separately in the weekly influenza update, FluView. Data from clinical laboratories include the weekly total number of specimens tested, the number of positive influenza test, and the percent positive by influenza type.
# REGION TYPE REGION               YEAR WEEK TOTAL SPECIMENS TOTAL A TOTAL B PERCENT POSITIVE PERCENT A                                          PERCENT B
# States      Alabama              2016 40   406             4       1       1.23             0.99                                                    0.25
#             Alaska               2016 40   X               X       X       X                X                                                          X
#             Arizona              2016 40   133             0       0       0                0                                                          0
#             Arkansas             2016 40   47              0       0       0                0                                                          0
#             California           2016 40   668             2       0       0.3              0.3                                                        0
#             Colorado             2016 40   260             0       0       0                0                                                          0
#             Connecticut          2016 40   199             3       0       1.51             1.51                                                       0
#             Delaware             2016 40   40              0       0       0                0                                                          0
#             District of Columbia 2016 40   X               X       X       X                X                                                          X

# %%
#view public
#pub_df = pd.DataFrame(pub_data)

#pub_df.head(10)

#clean public

# %%
#Combine the cleaned data into a single dataset

#mouse_study = pd.DataFrame.merge(mouse_metadata, study_results, how="inner", on="Mouse ID")
